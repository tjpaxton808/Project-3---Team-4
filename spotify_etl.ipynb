# %%
import requests
import pandas as pd

# %%
BASE_URL = "https://api.deezer.com"

def fetch_data(endpoint, params=None):
    """Generic function to fetch data from the Deezer API."""
    try:
        response = requests.get(f"{BASE_URL}{endpoint}", params=params)
        response.raise_for_status()  # Raise HTTP errors
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
def fetch_artists(artist_names):
    """Fetch basic data for a list of artist names."""
    artists = []
    for name in artist_names:
        data = fetch_data(f"/search/artist", params={"q": name})
        if data and "data" in data and len(data["data"]) > 0:
            artist = data["data"][0]  # Get the first search result
            artists.append({
                "artist_id": artist["id"],
                "name": artist["name"],
                "nb_fan": artist.get("nb_fan", 0),
                "link": artist.get("link", "N/A")
            })
    return artists

# %%
def fetch_artist_details(artist_ids):
    """Fetch detailed data for a list of artist IDs."""
    detailed_artists = []
    for artist_id in artist_ids:
        data = fetch_data(f"/artist/{artist_id}")
        if data:
            detailed_artists.append({
                "artist_id": data["id"],
                "name": data["name"],
                "nb_fan": data.get("nb_fan", 0),
                "nb_album": data.get("nb_album", 0),
                "radio": data.get("radio", False),
                "link": data.get("link", "N/A")
            })
    return detailed_artists

# %%
artist_names = [
    "Kip Moore",
    "Breaking Benjamin",
    "Dermot Kennedy",
    "Bad Omens",
    "Sultan + Shepard",
    "Taylor Swift",
    "Shawn Mendes",
    "Katy Perry",
    "Meghan Trainor",
    "Ariana Grande",
    "I Prevail",
    "Our Last Night",
    "Chappell Roan",
    "girl in red",
    "Maisie Peters",
    "Central Cee",
    "Drake",
    "Vince Staples",
    "Lil Yachty",
    "Lil Tecca",
    "Ed Sheeran",
    "Billie Eilish",
    "Post Malone",
    "Dua Lipa",
    "The Weeknd",
    "Imagine Dragons",
    "Adele",
    "Bruno Mars",
    "BTS",
    "Maroon 5",
    "Justin Bieber",
    "Cardi B",
    "Travis Scott",
    "Halsey",
    "Khalid",
    "Sam Smith",
    "Lizzo",
    "Harry Styles",
    "J Balvin",
    "Bad Bunny",
    "Doja Cat",
    "Olivia Rodrigo",
    "SZA",
    "Lil Nas X",
    "Megan Thee Stallion",
    "BLACKPINK",
    "Camila Cabello",
    "Jonas Brothers",
    "Nicki Minaj"
]

# %%
artists = fetch_artists(artist_names)

# Step 2: Fetch detailed artist info using their IDs
artist_ids = [artist["artist_id"] for artist in artists]
detailed_artists = fetch_artist_details(artist_ids)

# Convert to DataFrame for easy viewing
artist_df = pd.DataFrame(detailed_artists)
artist_df
# Out:
#     artist_id                 name    nb_fan  nb_album  radio  \
# 0     1436111            Kip Moore     40467        41   True
# 1        5286    Breaking Benjamin    665489        22   True
# 2    12033224       Dermot Kennedy    150432        45   True
# 3     9700940            Bad Omens     91209        19   True
# 4     7584298     Sultan + Shepard     28254        14   True
# 5       12246         Taylor Swift  11570273       103   True
# 6     5962948         Shawn Mendes   6546240        38   True
# 7      144227           Katy Perry   9336113        75   True
# 8     1181430       Meghan Trainor   1654072        75   True
# 9     1562681        Ariana Grande  12867203        55   True
# 10    7185748            I Prevail    133652        18   True
# 11      68249       Our Last Night    108648       146   True
# 12   12945219        Chappell Roan     81747        17   True
# 13   14226477          girl in red    698263        27   True
# 14   13022633        Maisie Peters     51352        58   True
# 15   12096038          Central Cee    485265        56   True
# 16     246791                Drake  23335479        69   True
# 17    4037971        Vince Staples     77616        27   True
# 18    9776678           Lil Yachty    419055        70   True
# 19   14492701            Lil Tecca    608266        38   True
# 20     384236           Ed Sheeran  20068165       130   True
# 21    9635624        Billie Eilish   8299134        31   True
# 22    7543848          Post Malone   3914169        36   True
# 23    8706544             Dua Lipa   8216285       108   True
# 24    4050205           The Weeknd  13179087        84   True
# 25     416239      Imagine Dragons   8714132        63   True
# 26      75798                Adele  14648658        15   True
# 27     429675           Bruno Mars  11639298        29   True
# 28    6982223                  BTS   3548878        83   True
# 29       1188             Maroon 5  11035233        58   True
# 30     288166        Justin Bieber  10696602        56   True
# 31    9064930              Cardi B   2402029        70   True
# 32    4495513         Travis Scott   2719690        54   True
# 33    5292512               Halsey   1963875        48   True
# 34     362326               Khalid   1693146        88   True
# 35    1097709            Sam Smith   5364856        48   True
# 36    5200025                Lizzo    419141        42   True
# 37    5313805         Harry Styles   1973723         5   True
# 38    4860761             J Balvin  10157198       152   True
# 39   10583405            Bad Bunny   6884138        90   True
# 40    5578942             Doja Cat   2216772        56   True
# 41   11152580       Olivia Rodrigo   1440212        21   True
# 42    5531258                  SZA   1017700        36   True
# 43   15166511            Lil Nas X   1658494        30   True
# 44   12816021  Megan Thee Stallion    827190        93   True
# 45   10803980            BLACKPINK   2324252        17   True
# 46    9236850       Camila Cabello   3714042        40   True
# 47      15888       Jonas Brothers   1645013        45   True
# 48     382937          Nicki Minaj   7149198        98   True
#
#                                       link
# 0    https://www.deezer.com/artist/1436111
# 1       https://www.deezer.com/artist/5286
# 2   https://www.deezer.com/artist/12033224
# 3    https://www.deezer.com/artist/9700940
# 4    https://www.deezer.com/artist/7584298
# 5      https://www.deezer.com/artist/12246
# 6    https://www.deezer.com/artist/5962948
# 7     https://www.deezer.com/artist/144227
# 8    https://www.deezer.com/artist/1181430
# 9    https://www.deezer.com/artist/1562681
# 10   https://www.deezer.com/artist/7185748
# 11     https://www.deezer.com/artist/68249
# 12  https://www.deezer.com/artist/12945219
# 13  https://www.deezer.com/artist/14226477
# 14  https://www.deezer.com/artist/13022633
# 15  https://www.deezer.com/artist/12096038
# 16    https://www.deezer.com/artist/246791
# 17   https://www.deezer.com/artist/4037971
# 18   https://www.deezer.com/artist/9776678
# 19  https://www.deezer.com/artist/14492701
# 20    https://www.deezer.com/artist/384236
# 21   https://www.deezer.com/artist/9635624
# 22   https://www.deezer.com/artist/7543848
# 23   https://www.deezer.com/artist/8706544
# 24   https://www.deezer.com/artist/4050205
# 25    https://www.deezer.com/artist/416239
# 26     https://www.deezer.com/artist/75798
# 27    https://www.deezer.com/artist/429675
# 28   https://www.deezer.com/artist/6982223
# 29      https://www.deezer.com/artist/1188
# 30    https://www.deezer.com/artist/288166
# 31   https://www.deezer.com/artist/9064930
# 32   https://www.deezer.com/artist/4495513
# 33   https://www.deezer.com/artist/5292512
# 34    https://www.deezer.com/artist/362326
# 35   https://www.deezer.com/artist/1097709
# 36   https://www.deezer.com/artist/5200025
# 37   https://www.deezer.com/artist/5313805
# 38   https://www.deezer.com/artist/4860761
# 39  https://www.deezer.com/artist/10583405
# 40   https://www.deezer.com/artist/5578942
# 41  https://www.deezer.com/artist/11152580
# 42   https://www.deezer.com/artist/5531258
# 43  https://www.deezer.com/artist/15166511
# 44  https://www.deezer.com/artist/12816021
# 45  https://www.deezer.com/artist/10803980
# 46   https://www.deezer.com/artist/9236850
# 47     https://www.deezer.com/artist/15888
# 48    https://www.deezer.com/artist/382937

# %%
# Function to fetch an artist's top tracks
def fetch_artist_top_tracks(artist_ids):
    """Fetch the top tracks for a given artist ID."""
    endpoint = f"/artist/{artist_ids}/top"
    data = fetch_data(endpoint)
    tracks = []
    
    if data and "data" in data:
        for track in data["data"]:
            tracks.append({
                "track_id": track["id"],
                "title": track["title"],
                "album_name": track["album"]["title"] if "album" in track else "N/A",
                "rank": track.get("rank", "N/A"),
                "duration": track.get("duration", "N/A"),
                "explicit_lyrics": track.get("explicit_lyrics", "N/A")
            })
    return tracks

# Fetch top tracks for all artists in the DataFrame
all_top_tracks = []
for _, artist in artist_df.iterrows():
    print(f"Fetching top tracks for artist: {artist['name']} (ID: {artist['artist_id']})...")
    top_tracks = fetch_artist_top_tracks(artist["artist_id"])
    for track in top_tracks:
        track["artist_id"] = artist["artist_id"]  # Link track to artist
    all_top_tracks.extend(top_tracks)

# Convert top tracks to a DataFrame
top_tracks_df = pd.DataFrame(all_top_tracks)
top_tracks_df
# Out:
# Fetching top tracks for artist: Kip Moore (ID: 1436111)...
# Fetching top tracks for artist: Breaking Benjamin (ID: 5286)...
# Fetching top tracks for artist: Dermot Kennedy (ID: 12033224)...
# Fetching top tracks for artist: Bad Omens (ID: 9700940)...
# Fetching top tracks for artist: Sultan + Shepard (ID: 7584298)...
# Fetching top tracks for artist: Taylor Swift (ID: 12246)...
# Fetching top tracks for artist: Shawn Mendes (ID: 5962948)...
# Fetching top tracks for artist: Katy Perry (ID: 144227)...
# Fetching top tracks for artist: Meghan Trainor (ID: 1181430)...
# Fetching top tracks for artist: Ariana Grande (ID: 1562681)...
# Fetching top tracks for artist: I Prevail (ID: 7185748)...
# Fetching top tracks for artist: Our Last Night (ID: 68249)...
# Fetching top tracks for artist: Chappell Roan (ID: 12945219)...
# Fetching top tracks for artist: girl in red (ID: 14226477)...
# Fetching top tracks for artist: Maisie Peters (ID: 13022633)...
# Fetching top tracks for artist: Central Cee (ID: 12096038)...
# Fetching top tracks for artist: Drake (ID: 246791)...
# Fetching top tracks for artist: Vince Staples (ID: 4037971)...
# Fetching top tracks for artist: Lil Yachty (ID: 9776678)...
# Fetching top tracks for artist: Lil Tecca (ID: 14492701)...
# Fetching top tracks for artist: Ed Sheeran (ID: 384236)...
# Fetching top tracks for artist: Billie Eilish (ID: 9635624)...
# Fetching top tracks for artist: Post Malone (ID: 7543848)...
# Fetching top tracks for artist: Dua Lipa (ID: 8706544)...
# Fetching top tracks for artist: The Weeknd (ID: 4050205)...
# Fetching top tracks for artist: Imagine Dragons (ID: 416239)...
# Fetching top tracks for artist: Adele (ID: 75798)...
# Fetching top tracks for artist: Bruno Mars (ID: 429675)...
# Fetching top tracks for artist: BTS (ID: 6982223)...
# Fetching top tracks for artist: Maroon 5 (ID: 1188)...
# Fetching top tracks for artist: Justin Bieber (ID: 288166)...
# Fetching top tracks for artist: Cardi B (ID: 9064930)...
# Fetching top tracks for artist: Travis Scott (ID: 4495513)...
# Fetching top tracks for artist: Halsey (ID: 5292512)...
# Fetching top tracks for artist: Khalid (ID: 362326)...
# Fetching top tracks for artist: Sam Smith (ID: 1097709)...
# Fetching top tracks for artist: Lizzo (ID: 5200025)...
# Fetching top tracks for artist: Harry Styles (ID: 5313805)...
# Fetching top tracks for artist: J Balvin (ID: 4860761)...
# Fetching top tracks for artist: Bad Bunny (ID: 10583405)...
# Fetching top tracks for artist: Doja Cat (ID: 5578942)...
# Fetching top tracks for artist: Olivia Rodrigo (ID: 11152580)...
# Fetching top tracks for artist: SZA (ID: 5531258)...
# Fetching top tracks for artist: Lil Nas X (ID: 15166511)...
# Fetching top tracks for artist: Megan Thee Stallion (ID: 12816021)...
# Fetching top tracks for artist: BLACKPINK (ID: 10803980)...
# Fetching top tracks for artist: Camila Cabello (ID: 9236850)...
# Fetching top tracks for artist: Jonas Brothers (ID: 15888)...
# Fetching top tracks for artist: Nicki Minaj (ID: 382937)...
#        track_id                    title  \
# 0    3123161771                 Bad Spot
# 1      18228848  Somethin' 'Bout A Truck
# 2    2958082621        Live Here To Work
# 3      18228846               Beer Money
# 4      18228855          Hey Pretty Girl
# ..          ...                      ...
# 240    28852751                Starships
# 241  1372275062    Best I Ever Had Remix
# 242   412843352               Super Bass
# 243    94195822           Truffle Butter
# 244   796342592                     Tusa
#
#                                   album_name    rank  duration  \
# 0                                   Bad Spot  548153       198
# 1                               Up All Night  326243       213
# 2                          Live Here To Work  549706       282
# 3                               Up All Night  290094       218
# 4                               Up All Night  302931       215
# ..                                       ...     ...       ...
# 240  Pink Friday ... Roman Reloaded (Deluxe)  937480       210
# 241                        Beam Me Up Scotty  371950       325
# 242             Pink Friday (Deluxe Edition)  712380       201
# 243                           Truffle Butter  500038       219
# 244                                     Tusa  888444       200
#
#      explicit_lyrics  artist_id
# 0              False    1436111
# 1              False    1436111
# 2               True    1436111
# 3              False    1436111
# 4              False    1436111
# ..               ...        ...
# 240             True     382937
# 241             True     382937
# 242            False     382937
# 243             True     382937
# 244            False     382937
#
# [245 rows x 7 columns]

# %%
cleaned_artist_df = artist_df.rename(columns={
        "artist_id": "Artist ID",
        "name": "Artist Name",
        "nb_fan": "Number of Fans",
        "nb_album": "Number of Albums",
        "radio": "Radio Available",
        "link": "Deezer Link"
    })
cleaned_artist_df = cleaned_artist_df.drop(columns=["Radio Available"])
cleaned_artist_df["Fan to Album Ratio"] = cleaned_artist_df["Number of Fans"] / cleaned_artist_df["Number of Albums"]
cleaned_artist_df.head()
# Out:
#    Artist ID        Artist Name  Number of Fans  Number of Albums  \
# 0    1436111          Kip Moore           40467                41
# 1       5286  Breaking Benjamin          665489                22
# 2   12033224     Dermot Kennedy          150432                45
# 3    9700940          Bad Omens           91209                19
# 4    7584298   Sultan + Shepard           28254                14
#
#                               Deezer Link  Fan to Album Ratio
# 0   https://www.deezer.com/artist/1436111          987.000000
# 1      https://www.deezer.com/artist/5286        30249.500000
# 2  https://www.deezer.com/artist/12033224         3342.933333
# 3   https://www.deezer.com/artist/9700940         4800.473684
# 4   https://www.deezer.com/artist/7584298         2018.142857

# %%
cleaned_track_df = top_tracks_df.rename(columns={
        "track_id": "Track ID",
        "title": "Track Title",
        "album_name": "Album Name",
        "rank": "Popularity Rank",
        "duration": "Duration (seconds)",
        "explicit_lyrics": "Explicit Lyrics",
        "artist_id": "Artist ID" 
})
cleaned_track_df["Duration (min:sec)"] = cleaned_track_df["Duration (seconds)"].apply(
    lambda x: f"{x // 60}:{x % 60:02}"
)
cleaned_track_df = cleaned_track_df.drop(columns=["Explicit Lyrics"], axis=1)
cleaned_track_df
# Out:
#        Track ID              Track Title  \
# 0    3123161771                 Bad Spot
# 1      18228848  Somethin' 'Bout A Truck
# 2    2958082621        Live Here To Work
# 3      18228846               Beer Money
# 4      18228855          Hey Pretty Girl
# ..          ...                      ...
# 240    28852751                Starships
# 241  1372275062    Best I Ever Had Remix
# 242   412843352               Super Bass
# 243    94195822           Truffle Butter
# 244   796342592                     Tusa
#
#                                   Album Name  Popularity Rank  \
# 0                                   Bad Spot           548153
# 1                               Up All Night           326243
# 2                          Live Here To Work           549706
# 3                               Up All Night           290094
# 4                               Up All Night           302931
# ..                                       ...              ...
# 240  Pink Friday ... Roman Reloaded (Deluxe)           937480
# 241                        Beam Me Up Scotty           371950
# 242             Pink Friday (Deluxe Edition)           712380
# 243                           Truffle Butter           500038
# 244                                     Tusa           888444
#
#      Duration (seconds)  Artist ID Duration (min:sec)
# 0                   198    1436111               3:18
# 1                   213    1436111               3:33
# 2                   282    1436111               4:42
# 3                   218    1436111               3:38
# 4                   215    1436111               3:35
# ..                  ...        ...                ...
# 240                 210     382937               3:30
# 241                 325     382937               5:25
# 242                 201     382937               3:21
# 243                 219     382937               3:39
# 244                 200     382937               3:20
#
# [245 rows x 7 columns]

# %%
cleaned_artist_df.to_csv("cleaned_artist_data.csv", index=False)
cleaned_track_df.to_csv("cleaned_tracks_data.csv", index=False)

# %%
cleaned_track_df = pd.read_csv('cleaned_tracks_data.csv')

# %%
if 'index' in cleaned_track_df.columns or 'level_0' in cleaned_track_df.columns:
    cleaned_track_df.drop(columns=['index', 'level_0'], errors='ignore', inplace=True)

# %%
cleaned_track_df.reset_index(inplace=True)
cleaned_track_df.rename(columns={'index': 'entry_key'}, inplace=True)
cleaned_track_df['entry_key'] += 1
cleaned_track_df.to_csv('cleaned_tracks_data.csv', index=False)
